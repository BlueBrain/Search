# %%
from pathlib import Path
from collections import defaultdict
import sqlite3
from time import time

import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_hub as hub

import torch

import sent2vec
from nltk import word_tokenize
from nltk.corpus import stopwords
from string import punctuation
from sentence_transformers import SentenceTransformer

# %%
data_path = Path("../data/2020-04-08")

cord_path = data_path / "CORD-19-research-challenge"
databases_path = data_path / "databases"
embeddings_path = data_path / "embeddings"
assets_path = Path("../assets")

assert data_path.exists()
assert cord_path.exists()
assert databases_path.exists()
assert embeddings_path.exists()
assert assets_path.exists()

# %%
# import nltk

# nltk.download('stopwords')
# nltk.download('punkt')

# %%
# Load universal sentence encoder
univsentenc_version = 5
univsentenc_embedder = hub.load(f"https://tfhub.dev/google/universal-sentence-encoder-large/{univsentenc_version}")
# Out:
# INFO:absl:Using /tmp/tfhub_modules to cache modules.

# %%
# Load SBERT
sbert_embedder = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
# %%time

# Load BioSentVec
bsv_embedder = sent2vec.Sent2vecModel()
bsv_embedder.load_model(str(assets_path / 'BioSentVec_PubMed_MIMICIII-bigram_d700.bin'))

bsv_stopwords = set(stopwords.words('english'))

def bsv_preprocess(text):
    text = text.replace('/', ' / ')
    text = text.replace('.-', ' .- ')
    text = text.replace('.', ' . ')
    text = text.replace('\'', ' \' ')
    text = text.lower()
    tokens = [token for token in word_tokenize(text)
              if token not in punctuation and token not in bsv_stopwords]
    return ' '.join(tokens)
# Out:
# CPU times: user 2.33 s, sys: 12.1 s, total: 14.4 s
# Wall time: 14.3 s

# %%
synonyms_dict = dict()
with open(assets_path / 'synonyms_list.txt', 'r', encoding='utf-8-sig') as f:
    for l in [l_.strip().lower() for l_ in f]:
        if l:
            w = [l_.strip() for l_ in l.split('=')]
            synonyms_dict[w[0]] = w[1:]

# %%
del synonyms_dict['sars']

# %%
synonyms_index = {x.lower(): k.lower() for k,v in synonyms_dict.items() for x in v}

# %%
def sent_preprocessing(sentences, 
                      synonyms_index):
    """Preprocessing of the sentences. (Lower + Split + Replace Synonym)
    
    Parameters
    ----------
    sentences : List[str]
        List of N strings.
    synonyms_index: dict
        Dictionary containing as key the synonym term and as values the reference of this term.
    """
    
    return [" ".join(synonyms_index.get(y, y) for y in word_tokenize(x.lower()))
            for x in sentences]

# %%
def embed_sentences(sentences,
                    embedding_name,
                    embedding_model):
    '''Sentence embedding.
    
    Parameters
    ----------
    sentences : List[str]
        List of N strings.
    embedding_name : str
        Name of the embedding type. One of ('USE', 'SBERT', 'BSV').
    embedding_model : tf.Model or torch.Module
        Neural net model to create sentence embeddings.
        
    Return
    ------
    encodded_sentences : np.ndarray
        Numpy array of shape (N, n_dims).
    '''
    if embedding_name == 'USE':
        return embedding_model(sentences).numpy()
    
    elif embedding_name == 'SBERT':
        return np.stack(embedding_model.encode(sentences), axis=0)
    
    elif embedding_name == 'BSV':
        preprocessed = [bsv_preprocess(x) for x in sentences]
        return embedding_model.embed_sentences(preprocessed)
        
    else:
        raise NotImplementedError(f'Embedding {repr(embedding_name)} not '
                                  f'available!')

# %%
db_filename = str(databases_path / 'articles.sqlite')
db = sqlite3.connect(db_filename)
curs = db.cursor()

# %%
def create_sentence_embeddings(preprocessing=False):

    embedding_names = ['USE', 'SBERT', 'BSV']
    embedding_models = [univsentenc_embedder, sbert_embedder, bsv_embedder]


    batch_size = 1_000

    x = defaultdict(list)
    arr = defaultdict(list)
    all_ids = []

    curs.execute('SELECT Id, Text FROM sections WHERE Tags IS NOT NULL')
    i = 0
    t0 = time()
    while True:
        i += 1
        batch = curs.fetchmany(batch_size)
        if not batch:
            break
        ids, sentences = zip(*batch)  

        all_ids.extend(ids)

        if preprocessing:
            sentences = sent_preprocessing(sentences, synonyms_index)

        for embedding_name, embedding_model in zip(embedding_names,
                                                       embedding_models):
            x_ = embed_sentences(sentences, 
                                 embedding_name=embedding_name, 
                                 embedding_model=embedding_model)
            x[embedding_name].append(x_)

        print(f'Done processing {batch_size * i} in {time()-t0:.1f} s.')


    print('Concatenate...')

    for embedding_name in embedding_names:
        print(f'processing: {embedding_name}')
        # Concatenate
        xx = np.concatenate(x[embedding_name], axis=0)
        all_ids = np.array(all_ids).reshape((-1, 1))
        arr[embedding_name] = np.concatenate((all_ids, xx), axis=1)
    
    print('Save...')

    if preprocessing:
        file_name = "sentence_embeddings_merged_synonyms.npz"
    else:
        file_name = "sentence_embeddings.npz"
    
    np.savez_compressed(file=str(embeddings_path / file_name), **arr)

# %%
# %%time
create_sentence_embeddings(preprocessing=False)
# Out:
# Done processing 1000 in 9.8 s.
# Done processing 2000 in 16.0 s.
# Done processing 3000 in 21.0 s.
# Done processing 4000 in 26.5 s.
# Done processing 5000 in 34.3 s.
# Done processing 6000 in 41.4 s.
# Done processing 7000 in 47.3 s.
# Done processing 8000 in 52.8 s.
# Done processing 9000 in 58.8 s.
# Done processing 10000 in 64.4 s.
# Done processing 11000 in 70.2 s.
# Done processing 12000 in 75.4 s.
# Done processing 13000 in 80.5 s.
# Done processing 14000 in 85.5 s.
# Done processing 15000 in 92.0 s.
# Done processing 16000 in 98.9 s.
# Done processing 17000 in 105.0 s.
# Done processing 18000 in 110.8 s.
# Done processing 19000 in 116.7 s.
# Done processing 20000 in 122.3 s.
# Done processing 21000 in 128.4 s.
# Done processing 22000 in 133.7 s.
# Done processing 23000 in 139.9 s.
# Done processing 24000 in 145.5 s.
# Done processing 25000 in 151.2 s.
# Done processing 26000 in 157.7 s.
# Done processing 27000 in 164.0 s.
# Done processing 28000 in 169.3 s.
# Done processing 29000 in 176.6 s.
# Done processing 30000 in 182.2 s.
# Done processing 31000 in 188.3 s.
# Done processing 32000 in 193.9 s.
# Done processing 33000 in 217.7 s.
# Done processing 34000 in 223.7 s.
# Done processing 35000 in 229.0 s.
# Done processing 36000 in 234.5 s.
# Done processing 37000 in 240.8 s.
# Done processing 38000 in 247.3 s.
# Done processing 39000 in 253.6 s.
# Done processing 40000 in 261.4 s.
# Done processing 41000 in 267.0 s.
# Done processing 42000 in 272.5 s.
# Done processing 43000 in 278.7 s.
# Done processing 44000 in 284.5 s.
# Done processing 45000 in 290.1 s.
# Done processing 46000 in 295.8 s.
# Done processing 47000 in 301.1 s.
# Done processing 48000 in 306.8 s.
# Done processing 49000 in 312.0 s.
# Done processing 50000 in 317.5 s.
# Done processing 51000 in 322.8 s.
# Done processing 52000 in 355.2 s.
# Done processing 53000 in 433.4 s.
# Done processing 54000 in 438.6 s.
# Done processing 55000 in 444.2 s.
# Done processing 56000 in 449.3 s.
# Done processing 57000 in 455.2 s.
# Done processing 58000 in 460.2 s.
# Done processing 59000 in 465.0 s.
# Done processing 60000 in 471.3 s.
# Done processing 61000 in 476.8 s.
# Done processing 62000 in 483.2 s.
# Done processing 63000 in 488.9 s.
# Done processing 64000 in 494.4 s.
# Done processing 65000 in 499.4 s.
# Done processing 66000 in 505.0 s.
# Done processing 67000 in 512.0 s.
# Done processing 68000 in 516.8 s.
# Done processing 69000 in 521.5 s.
# Done processing 70000 in 527.1 s.
# Done processing 71000 in 533.9 s.
# Done processing 72000 in 539.2 s.
# Done processing 73000 in 545.3 s.
# Done processing 74000 in 550.2 s.
# Done processing 75000 in 556.7 s.
# Done processing 76000 in 562.0 s.
# Done processing 77000 in 567.1 s.
# Done processing 78000 in 571.7 s.
# Done processing 79000 in 576.7 s.
# Done processing 80000 in 582.8 s.
# Done processing 81000 in 588.5 s.
# Done processing 82000 in 593.8 s.
# Done processing 83000 in 599.2 s.
# Done processing 84000 in 605.4 s.
# Done processing 85000 in 612.6 s.
# Done processing 86000 in 617.4 s.
# Done processing 87000 in 622.3 s.
# Done processing 88000 in 627.1 s.
# Done processing 89000 in 633.4 s.
# Done processing 90000 in 638.6 s.
# Done processing 91000 in 644.9 s.
# Done processing 92000 in 650.8 s.
# Done processing 93000 in 656.7 s.
# Done processing 94000 in 661.8 s.
# Done processing 95000 in 667.3 s.
# Done processing 96000 in 672.5 s.
# Done processing 97000 in 679.6 s.
# Done processing 98000 in 712.1 s.
# Done processing 99000 in 718.1 s.
# Done processing 100000 in 723.0 s.
# Done processing 101000 in 729.4 s.
# Done processing 102000 in 826.5 s.
# Done processing 103000 in 832.1 s.
# Done processing 104000 in 838.1 s.
# Done processing 105000 in 843.7 s.
# Done processing 106000 in 849.2 s.
# Done processing 107000 in 854.5 s.
# Done processing 108000 in 859.7 s.
# Done processing 109000 in 864.7 s.
# Done processing 110000 in 869.8 s.
# Done processing 111000 in 875.7 s.
# Done processing 112000 in 881.6 s.
# Done processing 113000 in 888.5 s.
# Done processing 114000 in 894.0 s.
# Done processing 115000 in 898.7 s.
# Done processing 116000 in 920.6 s.
# Done processing 117000 in 927.7 s.
# Done processing 118000 in 933.4 s.
# Done processing 119000 in 938.2 s.
# Done processing 120000 in 944.3 s.
# Done processing 121000 in 949.5 s.
# Done processing 122000 in 955.2 s.
# Done processing 123000 in 960.4 s.
# Done processing 124000 in 965.9 s.
# Done processing 125000 in 971.4 s.
# Done processing 126000 in 976.8 s.
# Done processing 127000 in 982.5 s.
# Done processing 128000 in 987.4 s.
# Done processing 129000 in 993.1 s.
# Done processing 130000 in 998.4 s.
# Done processing 131000 in 1003.9 s.
# Done processing 132000 in 1009.5 s.
# Done processing 133000 in 1014.5 s.
# Done processing 134000 in 1043.6 s.
# Done processing 135000 in 1049.9 s.
# Done processing 136000 in 1054.9 s.
# Done processing 137000 in 1060.0 s.
# Done processing 138000 in 1065.2 s.
# Done processing 139000 in 1070.3 s.
# Done processing 140000 in 1075.0 s.
# Done processing 141000 in 1080.4 s.
# Done processing 142000 in 1085.3 s.
# Done processing 143000 in 1091.0 s.
# Done processing 144000 in 1097.9 s.
# Done processing 145000 in 1103.4 s.
# Done processing 146000 in 1109.0 s.
# Done processing 147000 in 1115.5 s.
# Done processing 148000 in 1121.0 s.
# Done processing 149000 in 1126.3 s.
# Done processing 150000 in 1154.0 s.
# Done processing 151000 in 1160.0 s.
# Done processing 152000 in 1165.3 s.
# Done processing 153000 in 1170.2 s.
# Done processing 154000 in 1175.3 s.
# Done processing 155000 in 1180.4 s.
# Done processing 156000 in 1186.1 s.
# Done processing 157000 in 1194.8 s.
# Done processing 158000 in 1200.9 s.
# Done processing 159000 in 1206.5 s.
# Done processing 160000 in 1212.4 s.
# Done processing 161000 in 1218.0 s.
# Done processing 162000 in 1223.1 s.
# Done processing 163000 in 1229.5 s.
# Done processing 164000 in 1235.6 s.
# Done processing 165000 in 1242.7 s.
# Done processing 166000 in 1249.6 s.
# Done processing 167000 in 1257.3 s.
# Done processing 168000 in 1264.1 s.
# Done processing 169000 in 1270.7 s.
# Done processing 170000 in 1276.5 s.
# Done processing 171000 in 1281.7 s.
# Done processing 172000 in 1287.2 s.
# Done processing 173000 in 1292.7 s.
# Done processing 174000 in 1299.5 s.
# Done processing 175000 in 1307.0 s.
# Done processing 176000 in 1313.2 s.
# Done processing 177000 in 1318.7 s.
# Done processing 178000 in 1324.8 s.
# Done processing 179000 in 1330.9 s.
# Done processing 180000 in 1336.7 s.
# Done processing 181000 in 1342.5 s.
# Done processing 182000 in 1348.1 s.
# Done processing 183000 in 1353.0 s.
# Done processing 184000 in 1384.4 s.
# Done processing 185000 in 1390.8 s.
# Done processing 186000 in 1396.1 s.
# Done processing 187000 in 1403.9 s.
# Done processing 188000 in 1409.8 s.
# Done processing 189000 in 1414.8 s.
# Done processing 190000 in 1420.5 s.
# Done processing 191000 in 1426.4 s.
# Done processing 192000 in 1431.8 s.
# Done processing 193000 in 1437.7 s.
# Done processing 194000 in 1443.3 s.
# Done processing 195000 in 1449.4 s.
# Done processing 196000 in 1455.8 s.
# Done processing 197000 in 1463.1 s.
# Done processing 198000 in 1469.2 s.
# Done processing 199000 in 1477.3 s.
# Done processing 200000 in 1483.3 s.
# Done processing 201000 in 1491.1 s.
# Done processing 202000 in 1496.0 s.
# Done processing 203000 in 1503.9 s.
# Done processing 204000 in 1510.7 s.
# Done processing 205000 in 1514.2 s.
# Concatenate...
# processing: USE
# processing: SBERT
# processing: BSV
# Save...
# CPU times: user 5h 40min 29s, sys: 5h 32min 4s, total: 11h 12min 34s
# Wall time: 31min 2s

# %%
# %%time
create_sentence_embeddings(preprocessing=True)
# Out:
# Done processing 1000 in 6.5 s.
# Done processing 2000 in 13.1 s.
# Done processing 3000 in 18.5 s.
# Done processing 4000 in 24.3 s.
# Done processing 5000 in 32.3 s.
# Done processing 6000 in 39.6 s.
# Done processing 7000 in 45.8 s.
# Done processing 8000 in 51.6 s.
# Done processing 9000 in 57.8 s.
# Done processing 10000 in 63.8 s.
# Done processing 11000 in 70.0 s.
# Done processing 12000 in 75.7 s.
# Done processing 13000 in 81.2 s.
# Done processing 14000 in 86.8 s.
# Done processing 15000 in 93.8 s.
# Done processing 16000 in 101.1 s.
# Done processing 17000 in 107.6 s.
# Done processing 18000 in 113.9 s.
# Done processing 19000 in 120.3 s.
# Done processing 20000 in 126.4 s.
# Done processing 21000 in 133.1 s.
# Done processing 22000 in 138.7 s.
# Done processing 23000 in 145.4 s.
# Done processing 24000 in 151.5 s.
# Done processing 25000 in 157.6 s.
# Done processing 26000 in 164.6 s.
# Done processing 27000 in 171.4 s.
# Done processing 28000 in 177.2 s.
# Done processing 29000 in 185.3 s.
# Done processing 30000 in 191.3 s.
# Done processing 31000 in 197.9 s.
# Done processing 32000 in 204.0 s.
# Done processing 33000 in 230.2 s.
# Done processing 34000 in 236.6 s.
# Done processing 35000 in 243.4 s.
# Done processing 36000 in 249.3 s.
# Done processing 37000 in 256.2 s.
# Done processing 38000 in 263.3 s.
# Done processing 39000 in 271.1 s.
# Done processing 40000 in 279.7 s.
# Done processing 41000 in 285.7 s.
# Done processing 42000 in 291.9 s.
# Done processing 43000 in 298.9 s.
# Done processing 44000 in 305.2 s.
# Done processing 45000 in 311.5 s.
# Done processing 46000 in 317.7 s.
# Done processing 47000 in 323.6 s.
# Done processing 48000 in 329.7 s.
# Done processing 49000 in 335.4 s.
# Done processing 50000 in 341.3 s.
# Done processing 51000 in 347.2 s.
# Done processing 52000 in 379.6 s.
# Done processing 53000 in 458.2 s.
# Done processing 54000 in 463.8 s.
# Done processing 55000 in 469.9 s.
# Done processing 56000 in 475.6 s.
# Done processing 57000 in 482.1 s.
# Done processing 58000 in 487.5 s.
# Done processing 59000 in 492.9 s.
# Done processing 60000 in 499.9 s.
# Done processing 61000 in 506.0 s.
# Done processing 62000 in 512.9 s.
# Done processing 63000 in 519.1 s.
# Done processing 64000 in 525.6 s.
# Done processing 65000 in 531.2 s.
# Done processing 66000 in 537.3 s.
# Done processing 67000 in 545.9 s.
# Done processing 68000 in 551.3 s.
# Done processing 69000 in 556.4 s.
# Done processing 70000 in 562.4 s.
# Done processing 71000 in 569.7 s.
# Done processing 72000 in 575.3 s.
# Done processing 73000 in 582.1 s.
# Done processing 74000 in 587.3 s.
# Done processing 75000 in 594.2 s.
# Done processing 76000 in 600.6 s.
# Done processing 77000 in 606.1 s.
# Done processing 78000 in 611.2 s.
# Done processing 79000 in 616.5 s.
# Done processing 80000 in 623.0 s.
# Done processing 81000 in 629.2 s.
# Done processing 82000 in 634.8 s.
# Done processing 83000 in 640.6 s.
# Done processing 84000 in 647.1 s.
# Done processing 85000 in 654.8 s.
# Done processing 86000 in 659.9 s.
# Done processing 87000 in 665.1 s.
# Done processing 88000 in 670.3 s.
# Done processing 89000 in 677.2 s.
# Done processing 90000 in 682.8 s.
# Done processing 91000 in 689.6 s.
# Done processing 92000 in 696.0 s.
# Done processing 93000 in 702.4 s.
# Done processing 94000 in 708.1 s.
# Done processing 95000 in 713.9 s.
# Done processing 96000 in 719.5 s.
# Done processing 97000 in 727.1 s.
# Done processing 98000 in 760.1 s.
# Done processing 99000 in 766.5 s.
# Done processing 100000 in 771.7 s.
# Done processing 101000 in 778.5 s.
# Done processing 102000 in 877.7 s.
# Done processing 103000 in 883.7 s.
# Done processing 104000 in 890.1 s.
# Done processing 105000 in 896.0 s.
# Done processing 106000 in 901.9 s.
# Done processing 107000 in 907.7 s.
# Done processing 108000 in 913.4 s.
# Done processing 109000 in 918.7 s.
# Done processing 110000 in 924.2 s.
# Done processing 111000 in 958.1 s.
# Done processing 112000 in 964.6 s.
# Done processing 113000 in 971.9 s.
# Done processing 114000 in 977.8 s.
# Done processing 115000 in 982.8 s.
# Done processing 116000 in 1004.4 s.
# Done processing 117000 in 1011.8 s.
# Done processing 118000 in 1018.0 s.
# Done processing 119000 in 1023.3 s.
# Done processing 120000 in 1029.8 s.
# Done processing 121000 in 1035.4 s.
# Done processing 122000 in 1041.6 s.
# Done processing 123000 in 1047.1 s.
# Done processing 124000 in 1053.0 s.
# Done processing 125000 in 1059.0 s.
# Done processing 126000 in 1064.8 s.
# Done processing 127000 in 1071.0 s.
# Done processing 128000 in 1076.4 s.
# Done processing 129000 in 1082.4 s.
# Done processing 130000 in 1088.1 s.
# Done processing 131000 in 1093.9 s.
# Done processing 132000 in 1099.9 s.
# Done processing 133000 in 1105.3 s.
# Done processing 134000 in 1132.6 s.
# Done processing 135000 in 1139.2 s.
# Done processing 136000 in 1144.5 s.
# Done processing 137000 in 1150.0 s.
# Done processing 138000 in 1155.5 s.
# Done processing 139000 in 1161.1 s.
# Done processing 140000 in 1166.3 s.
# Done processing 141000 in 1172.4 s.
# Done processing 142000 in 1177.9 s.
# Done processing 143000 in 1184.1 s.
# Done processing 144000 in 1191.5 s.
# Done processing 145000 in 1197.4 s.
# Done processing 146000 in 1203.5 s.
# Done processing 147000 in 1210.6 s.
# Done processing 148000 in 1216.6 s.
# Done processing 149000 in 1222.3 s.
# Done processing 150000 in 1251.5 s.
# Done processing 151000 in 1258.0 s.
# Done processing 152000 in 1263.7 s.
# Done processing 153000 in 1269.2 s.
# Done processing 154000 in 1274.7 s.
# Done processing 155000 in 1280.3 s.
# Done processing 156000 in 1286.4 s.
# Done processing 157000 in 1295.7 s.
# Done processing 158000 in 1302.3 s.
# Done processing 159000 in 1308.5 s.
# Done processing 160000 in 1314.8 s.
# Done processing 161000 in 1320.9 s.
# Done processing 162000 in 1326.4 s.
# Done processing 163000 in 1333.4 s.
# Done processing 164000 in 1340.1 s.
# Done processing 165000 in 1347.7 s.
# Done processing 166000 in 1355.3 s.
# Done processing 167000 in 1363.5 s.
# Done processing 168000 in 1373.0 s.
# Done processing 169000 in 1380.1 s.
# Done processing 170000 in 1386.4 s.
# Done processing 171000 in 1392.1 s.
# Done processing 172000 in 1398.0 s.
# Done processing 173000 in 1404.1 s.
# Done processing 174000 in 1411.5 s.
# Done processing 175000 in 1419.5 s.
# Done processing 176000 in 1426.2 s.
# Done processing 177000 in 1432.0 s.
# Done processing 178000 in 1438.7 s.
# Done processing 179000 in 1445.2 s.
# Done processing 180000 in 1451.4 s.
# Done processing 181000 in 1457.8 s.
# Done processing 182000 in 1463.9 s.
# Done processing 183000 in 1469.3 s.
# Done processing 184000 in 1501.3 s.
# Done processing 185000 in 1508.3 s.
# Done processing 186000 in 1514.0 s.
# Done processing 187000 in 1522.3 s.
# Done processing 188000 in 1528.6 s.
# Done processing 189000 in 1534.1 s.
# Done processing 190000 in 1540.3 s.
# Done processing 191000 in 1546.7 s.
# Done processing 192000 in 1552.6 s.
# Done processing 193000 in 1559.0 s.
# Done processing 194000 in 1564.9 s.
# Done processing 195000 in 1571.5 s.
# Done processing 196000 in 1578.4 s.
# Done processing 197000 in 1586.3 s.
# Done processing 198000 in 1592.9 s.
# Done processing 199000 in 1601.5 s.
# Done processing 200000 in 1608.3 s.
# Done processing 201000 in 1616.8 s.
# Done processing 202000 in 1622.2 s.
# Done processing 203000 in 1630.6 s.
# Done processing 204000 in 1638.1 s.
# Done processing 205000 in 1641.8 s.
# Concatenate...
# processing: USE
# processing: SBERT
# processing: BSV
# Save...
# CPU times: user 5h 54min 51s, sys: 5h 40min 1s, total: 11h 34min 52s
# Wall time: 33min 10s
